# %%
import pandas as pd
import numpy as np

MIN_LAT, MAX_LAT= 35.6845, 39.6945
MIN_LON, MAX_LON= 139.6945, 139.7055

NUM_INCIDENTS= 2000

# %%
# !pip install pandas numpy geopandas folium matplotlib seaborn shapely
# Out:
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------- -------------------------- 3.7/11.0 MB 19.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 17.6 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 15.5 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------- ----------------------------- 3.4/12.8 MB 15.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.8 MB 14.9 MB/s eta 0:00:01
# ...
